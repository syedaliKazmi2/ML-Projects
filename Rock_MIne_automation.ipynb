# %% [markdown]
# <a href="https://colab.research.google.com/github/syedaliKazmi2/ML-Projects/blob/main/Rock_MIne_automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
sonar_data= pd.read_csv('/content/Copy of sonar data.csv', header=None)

# %%
sonar_data.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.head(10)
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  ...  0.0167  0.0180  0.0084  0.0090  0.0032  R
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  ...  0.0191  0.0140  0.0049  0.0052  0.0044  R
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  ...  0.0244  0.0316  0.0164  0.0095  0.0078  R
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  ...  0.0073  0.0050  0.0044  0.0040  0.0117  R
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  ...  0.0015  0.0072  0.0048  0.0107  0.0094  R
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  ...  0.0089  0.0057  0.0027  0.0051  0.0062  R
# 5  0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  ...  0.0138  0.0092  0.0143  0.0036  0.0103  R
# 6  0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  ...  0.0097  0.0085  0.0047  0.0048  0.0053  R
# 7  0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  ...  0.0049  0.0065  0.0093  0.0059  0.0022  R
# 8  0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  ...  0.0068  0.0032  0.0035  0.0056  0.0040  R
# ...

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2         3   ...        56        57        58        59
# 60                                          ...
# M   0.034989  0.045544  0.050720  0.064768  ...  0.007825  0.009060  0.008695  0.006930
# R   0.022498  0.030303  0.035951  0.041447  ...  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
X= sonar_data.drop(60, axis=1)
Y=sonar_data[60]

# %%
print(X)
print(Y)
# Out:
#          0       1       2       3       4       5   ...      54      55      56      57      58      59
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  ...  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  ...  0.0094  0.0191  0.0140  0.0049  0.0052  0.0044
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  ...  0.0180  0.0244  0.0316  0.0164  0.0095  0.0078
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  ...  0.0085  0.0073  0.0050  0.0044  0.0040  0.0117
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  ...  0.0110  0.0015  0.0072  0.0048  0.0107  0.0094
# ..      ...     ...     ...     ...     ...     ...  ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  ...  0.0033  0.0101  0.0065  0.0115  0.0193  0.0157
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  ...  0.0063  0.0063  0.0034  0.0032  0.0062  0.0067
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,stratify=Y, random_state=1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %%
Y_train
# Out:
# 115    M
# 38     R
# 56     R
# 123    M
# 18     R
#       ..
# 140    M
# 5      R
# 154    M
# 131    M
# 203    M
# Name: 60, Length: 187, dtype: object

# %% [markdown]
# MOdel training Through logistic regression

# %%
model= LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# accuracy of training data
X_train_prediction = model.predict(X_train)
training_data_accuracy= accuracy_score(X_train_prediction,Y_train)

# %%
print('your accuracy is:',training_data_accuracy)
# Out:
# your accuracy is: 0.8342245989304813

# %%
#accuracy of test data
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('your test data accuracy is:',test_data_accuracy)
# Out:
# your test data accuracy is: 0.7619047619047619

# %%
inputdata=(0.0192,0.0607,0.0378,0.0774,0.1388,0.0809,0.0568,0.0219,0.1037,0.1186,0.1237,0.1601,0.3520,0.4479,0.3769,0.5761,0.6426,0.6790,0.7157,0.5466,0.5399,0.6362,0.7849,0.7756,0.5780,0.4862,0.4181,0.2457,0.0716,0.0613,0.1816,0.4493,0.5976,0.3785,0.2495,0.5771,0.8852,0.8409,0.3570,0.3133,0.6096,0.6378,0.2709,0.1419,0.1260,0.1288,0.0790,0.0829,0.0520,0.0216,0.0360,0.0331,0.0131,0.0120,0.0108,0.0024,0.0045,0.0037,0.0112,0.0075)
input_data_array=np.asarray(inputdata)
input_data_array_datareshaped=input_data_array.reshape(1,-1)
prediction=model.predict(input_data_array_datareshaped)
print(prediction)
if prediction[0]=='R':
  print('The Model is Rock')
else:
  print('the model is Mine')
# Out:
# ['R']
# The Model is Rock
